# %% [markdown]
# <a href="https://colab.research.google.com/github/muxlissarajabboyeva/Pandas/blob/main/series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
list=[10,20,30,40]
my_series=pd.Series([10,20,30,40])
print(list)
# Out:
# [10, 20, 30, 40]

# %%
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
