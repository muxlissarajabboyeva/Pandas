# %% [markdown]
# <a href="https://colab.research.google.com/github/muxlissarajabboyeva/Pandas/blob/main/series_continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dict_series=pd.Series({'a':1,'b':2,'c':3})
print(dict_series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
custom_index_series=pd.Series([100,200,300,400],index=['A','B','C','D'])
print(custom_index_series)
# Out:
# A    100
# B    200
# C    300
# D    400
# dtype: int64

# %%
#kesish
print(custom_index_series['C'])
# Out:
# 300

# %%
print(custom_index_series[])

# %%
list_series=pd.Series([10,20,30,40,50])
print(list_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(list_series[0:4])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
